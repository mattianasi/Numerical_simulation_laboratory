# %% [markdown]
# # <span style=color:blue> Numerical Simulation Laboratory #
# ## <span style=color:blue> Exercise lecture 12 ##
# ### Mattia Nasi 11590A ###

# %% [markdown]
# ## <span style=color:red> 12.1 ##
#
# This first exercise is about playing with a DNN trained on the MNIST dataset, this dataset contains numerous handwritten digits (0-9). First of all i built a standard infrastructure composed of 3 neuron layers, with activation function RELU, except for the output layers that uses a softmax to return a probability, and a final dropout layers that turns off 50% of the neurons to speed up slightly the training.
#
# Once this standard DNN model is composed i use it to compare 4 different optimizers with the same categorical_crossentropy loss function, this will be used to determine wich one is best fitted on this task and will be used in the real training of the DNN.
#
# The real test will be to try recognizing my handwritten digits, this is a test to understand if the network was able to generalize sufficiently.

# %%
import tensorflow as tf
from tensorflow import keras
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)

from keras.datasets import mnist

img_rows, img_cols = 28, 28 # number of pixels 
num_classes = 10 # 10 digits

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

#print('X_train shape:', X_train.shape) 
#print('Y_train shape:', Y_train.shape)

# %%
X_train = X_train.reshape(X_train.shape[0], img_rows*img_cols)
X_test = X_test.reshape(X_test.shape[0], img_rows*img_cols)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

def create_DNN():
    model = Sequential()
    model.add(Dense(256,input_shape=(img_rows*img_cols,), activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
from keras.optimizers import SGD, Adam, Adadelta, Adamax
optimizers = {
    'SGD': SGD(),
    'Adam': Adam(),
    'Adadelta': Adadelta(),
    'Adamax': Adamax()
}

batch_size = 32
epochs = 15
# Out:
# 2025-06-26 09:20:47.276828: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-06-26 09:20:47.277088: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-06-26 09:20:47.277129: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-06-26 09:20:47.277435: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-06-26 09:20:47.277502: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
histories = {}

# Train a model with each optimizer
for name, optimizer in optimizers.items():
    print(f"\nTraining with optimizer: {name}")
    model = create_DNN()
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=optimizer,
                  metrics=['accuracy'])

    history = model.fit(X_train, Y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        shuffle=True,
                        verbose=0,
                        validation_data=(X_test, Y_test))
    
    score = model.evaluate(X_test, Y_test, verbose=0)
    print(f"{name} - Test loss: {score[0]:.4f}, Test accuracy: {score[1]:.4f}")
    histories[name] = history
# Out:
# Training with optimizer: SGD
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-26 09:20:49.881293: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-06-26 09:20:49.882684: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# SGD - Test loss: 0.0827, Test accuracy: 0.9748
#
# Training with optimizer: Adam
# 2025-06-26 09:25:14.775282: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# ...

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 16))
fig.suptitle('Training History per Optimizer', fontsize=16)

for i, (name, history) in enumerate(histories.items()):
    # Accuracy plot
    axes[i, 0].plot(history.history['accuracy'], label='Train')
    axes[i, 0].plot(history.history['val_accuracy'], label='Validation')
    axes[i, 0].set_title(f'{name} - Accuracy')
    axes[i, 0].set_xlabel('Epoch')
    axes[i, 0].set_ylabel('Accuracy')
    axes[i, 0].legend()
    axes[i, 0].grid(True)

    # Loss plot
    axes[i, 1].plot(history.history['loss'], label='Train')
    axes[i, 1].plot(history.history['val_loss'], label='Validation')
    axes[i, 1].set_title(f'{name} - Loss')
    axes[i, 1].set_xlabel('Epoch')
    axes[i, 1].set_ylabel('Loss')
    axes[i, 1].legend()
    axes[i, 1].grid(True)

plt.tight_layout(rect=[0, 0, 1, 0.97])  # Leave space for the main title
plt.show()

# %% [markdown]
# Now that I determined that the best optimizer is Adamax the following training will implement it, i will use a larger number of epochs than the previous comparing run but, I  implemented an early stopping criteria that exits the training if the loss is not improving after 5 consecutive epochs, this might affect the results but certainly helps with the training time.

# %%
def compile_model():
    # create the model
    model=create_DNN()
    # compile the model
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=Adamax(),
                  metrics=['acc'])
    return model

from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',     # You can also use 'val_accuracy'
    patience=5,             # Stop after 5 epochs without improvement
    restore_best_weights=True,  # Revert to best weights
    verbose=1
)

# %%
batch_size = 32
epochs = 30

model_DNN = compile_model()

history = model_DNN.fit(X_train, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          verbose=1,
          callbacks=[early_stopping],
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/30
# 2025-06-26 09:47:31.734871: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - acc: 0.7800 - loss: 0.7247 - val_acc: 0.9493 - val_loss: 0.1688
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - acc: 0.9357 - loss: 0.2417 - val_acc: 0.9630 - val_loss: 0.1230
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - acc: 0.9539 - loss: 0.1718 - val_acc: 0.9692 - val_loss: 0.1010
# Epoch 4/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - acc: 0.9627 - loss: 0.1393 - val_acc: 0.9731 - val_loss: 0.0866
# Epoch 5/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - acc: 0.9705 - loss: 0.1118 - val_acc: 0.9766 - val_loss: 0.0763
# Epoch 6/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - acc: 0.9759 - loss: 0.0939 - val_acc: 0.9754 - val_loss: 0.0802
# Epoch 7/30
# ...

# %%
score = model_DNN.evaluate(X_test, Y_test, verbose=1)

print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.ylabel('model accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - acc: 0.9769 - loss: 0.0780
#
# Test loss: 0.06848098337650299
# Test accuracy: 0.9801999926567078

# %% [markdown]
# Here is the DNN prediction on a test dataset extracted from the MNIST one, just to check if the training went well.

# %%
predictions = model_DNN.predict(X_test)

X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols,1)

plt.figure(figsize=(15, 15)) 
for i in range(10):    
    ax = plt.subplot(2, 10, i + 1)    
    plt.imshow(X_test[i, :, :, 0], cmap='gray')    
    plt.title("Digit: {}\nPredicted:    {}".format(np.argmax(Y_test[i]), np.argmax(predictions[i])))    
    plt.axis('off') 
plt.show()
# Out:
#  89/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-06-26 10:12:05.148003: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ## <span style=color:red> 12.2 ##
#
# Now is time to implement a CNN, this structure is well fitted for classification tasks. Instead of a neuron layers composition like the DNN it consists of an alternation between convolutional and pooling layers, a final deep layer is used to maximise the ability to generalize.
#
# A convolutional layer works by appliyng a set of $n$ different filters to the initial image, this produces $n$ different copies of the image each with a peculiarity.
#
# A pooling layer works by reducing the quantity of information selecting, in the case of Maxpool as I used, the maximal value in a set of pixels, $2x2$ in this case.
#
# My CNN alternates two convolutional and two pooling layers, note that the convolutuional layers scan the image pixel by pixel when the pooling ones jump one each time. A final dropout layer is added before the output with activation function softmax necessary to produce probabilities.
#
# The optimizer is the same found to be the best in the previous exercise (maybe not the wisiest choice) and an early stopping is implemented in the training process to avoid unnecessary long training times.

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], img_rows*img_cols)
X_test = X_test.reshape(X_test.shape[0], img_rows*img_cols)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)

# %%
from keras.layers import Flatten, Conv2D, MaxPooling2D

if keras.backend.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %%
def create_CNN():
    # instantiate model
    model = Sequential()
    # add first convolutional layer with 10 filters (dimensionality of output space)
    model.add(Conv2D(6, kernel_size=(5, 5),
                     activation='relu',
                     strides=1,
                     input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
    model.add(Conv2D(16, kernel_size=(5, 5),
                     activation='relu',
                     strides=1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides = 2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile the model
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer='Adamax',
                  metrics=['acc'])
    return model

# %%
batch_size = 32
epochs = 30

# create the deep conv net
model_CNN=create_CNN()

# train CNN
historyC = model_CNN.fit(X_train, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          shuffle=True,
          verbose=1,
          callbacks=[early_stopping],
          validation_data=(X_test, Y_test))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 2025-06-26 13:14:13.943602: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 34s 18ms/step - acc: 0.7518 - loss: 0.7954 - val_acc: 0.9607 - val_loss: 0.1268
# Epoch 2/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - acc: 0.9390 - loss: 0.2060 - val_acc: 0.9725 - val_loss: 0.0864
# Epoch 3/30
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 17ms/step - acc: 0.9560 - loss: 0.1524 - val_acc: 0.9773 - val_loss: 0.0704
# Epoch 4/30
# ...

# %%
score = model_CNN.evaluate(X_test, Y_test, verbose=1)

print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

plt.plot(historyC.history['acc'])
plt.plot(historyC.history['val_acc'])
plt.ylabel('model accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

plt.plot(historyC.history['loss'])
plt.plot(historyC.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - acc: 0.9853 - loss: 0.0401
#
# Test loss: 0.0322885699570179
# Test accuracy: 0.9890000224113464

# %% [markdown]
# Here is, as before, the CNN performance on a MNIST dataset sample.

# %%
predictions = model_CNN.predict(X_test)

X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols,1)

plt.figure(figsize=(15, 15)) 
for i in range(10):    
    ax = plt.subplot(2, 10, i + 1)    
    plt.imshow(X_test[i, :, :, 0], cmap='gray')    
    plt.title("Digit: {}\nPredicted:    {}".format(np.argmax(Y_test[i]), np.argmax(predictions[i])))    
    plt.axis('off') 
plt.show()
# Out:
#  53/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2025-06-26 13:33:31.391624: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] PluggableGraphOptimizer failed: INVALID_ARGUMENT: Failed to deserialize the `graph_buf`.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ## <span style=color:red> 12.3 ##
#
# Finally here is the test of the DNN and CNN on a set of digits handwritten by me, with some digits altered from the bright and centered format of the MNIST, the two models will try to fit something different from the data they were trained on, if the predictions are good enough this is a strong indication of the succesful generalisation performed by the models.

# %%
from PIL import Image
import os
import matplotlib.pyplot as plt

folder_path = "./Numeri"
images = []
filenames = []

# Load images without any conversion or processing
for filename in sorted(os.listdir(folder_path)):
    if filename.endswith(".png"):
        filepath = os.path.join(folder_path, filename)
        img = Image.open(filepath)  # No .convert()
        images.append(img)
        filenames.append(filename)

# Plot all images in a single row
plt.figure(figsize=(len(images) * 2, 2))
for i, img in enumerate(images):
    ax = plt.subplot(1, len(images), i + 1)
    plt.imshow(img)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np

plt.figure(figsize=(len(images) * 2, 2))

for i, img in enumerate(images):
    # Convert to grayscale (model likely expects grayscale)
    digit_gray = img.convert('L')
    
    # Resize or get image size
    ydim, xdim = digit_gray.size
    
    # Convert to numpy array and normalize [0,1]
    data = np.array(digit_gray).astype('float32') / 255.0
    
    # Flatten to 1D array (assuming model input shape is (1, xdim*ydim))
    data = data.flatten().reshape(1, -1)
    
    # Predict with your model (replace model_DNN with your actual model)
    pred = model_DNN.predict(data)
    predicted_digit = np.argmax(pred)
    
    # Plot image and prediction
    ax = plt.subplot(1, len(images), i + 1)
    plt.imshow(img)
    plt.title(f"Pred: {predicted_digit}", fontsize=10)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(len(images) * 2, 2))

for i, img in enumerate(images):
    # Convert to grayscale and resize to 28x28 if needed
    digit_gray = img.convert('L').resize((28, 28))
    
    # Convert to numpy array and normalize
    data = np.array(digit_gray).astype('float32') / 255.0
    
    # Reshape to (1, 28, 28, 1)
    data = data.reshape(1, 28, 28, 1)    
    # Predict
    pred = model_CNN.predict(data)    
    predicted_digit = np.argmax(pred)
    
    # Plot original (resized) image and prediction
    ax = plt.subplot(1, len(images), i + 1)
    plt.imshow(data.reshape(28, 28), cmap='gray')
    plt.title(f"Digit predicted: {predicted_digit}", fontsize=10)
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# As one can see the CNN is way more accurate in performing this fit predicting 9 exact digits while the DNN only got 7 out of 10 correct predictions, this shows exactly that a CNN is certainly a better choice for this specific tasks.
